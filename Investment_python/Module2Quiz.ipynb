# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import scipy.stats
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize
import edhec_risk_kit_done as erk

hfi = erk.get_hfi_returns()
er = erk.annualize_rets(hfi["2000":], 12)
cov = hfi["2000":].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hfi
# Out:
#          Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 1997-01                 0.0119      0.0393                 0.0178
# 1997-02                 0.0123      0.0298                 0.0122
# 1997-03                 0.0078     -0.0021                -0.0012
# 1997-04                 0.0086     -0.0170                 0.0030
# 1997-05                 0.0156     -0.0015                 0.0233
# ...                        ...         ...                    ...
# 2018-07                 0.0021     -0.0058                 0.0093
# 2018-08                 0.0024      0.0166                 0.0002
# 2018-09                 0.0034     -0.0054                 0.0050
# 2018-10                -0.0073     -0.0314                -0.0158
# 2018-11                -0.0068     -0.0053                -0.0193
#
#          Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# 1997-01            0.0791                 0.0189        0.0213
# ...

# %%
er
# Out:
# Convertible Arbitrage     0.059325
# CTA Global                0.039409
# Distressed Securities     0.080837
# Emerging Markets          0.067518
# Equity Market Neutral     0.043420
# Event Driven              0.066692
# Fixed Income Arbitrage    0.052914
# Global Macro              0.051394
# Long/Short Equity         0.054580
# Merger Arbitrage          0.053831
# Relative Value            0.062064
# Short Selling            -0.039184
# Funds Of Funds            0.034125
# dtype: float64

# %%
cov
# Out:
#                         Convertible Arbitrage  CTA Global  \
# Convertible Arbitrage                0.000294    0.000003
# CTA Global                           0.000003    0.000538
# Distressed Securities                0.000206    0.000013
# Emerging Markets                     0.000306    0.000066
# Equity Market Neutral                0.000067    0.000038
# Event Driven                         0.000199    0.000023
# Fixed Income Arbitrage               0.000149    0.000012
# Global Macro                         0.000087    0.000188
# Long/Short Equity                    0.000200    0.000058
# Merger Arbitrage                     0.000082    0.000019
# Relative Value                       0.000167    0.000016
# Short Selling                       -0.000275    0.000096
# Funds Of Funds                       0.000159    0.000081
#
#                         Distressed Securities  Emerging Markets  \
# Convertible Arbitrage                0.000206          0.000306
# ...

# %%
erk.var_gaussian(hfi["2000":]["Distressed Securities"], level=1)
# Out:
# 0.03143017693928047

# %%
erk.var_gaussian(hfi["2000":]["Distressed Securities"], level=1, modified=True)
# Out:
# 0.04966909110627918

# %%
erk.var_historic(hfi["2000":]["Distressed Securities"], level=1)
# Out:
# 0.04264199999999999

# %%
ind = erk.get_ind_returns()
ind
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# ...

# %%
er = erk.annualize_rets(ind["2013":"2017"], 12)
cov = ind["2013":"2017"].cov()
l = ["Books", "Steel", "Oil", "Mines"]

# %%
erk.msr(.1, er[l], cov.loc[l,l])
# Out:
# array([4.51375048e-15, 1.00000000e+00, 1.40512602e-16, 0.00000000e+00])

# %%
erk.gmv(cov.loc[l,l])
# Out:
# array([4.77024870e-01, 4.33680869e-19, 4.34112024e-01, 8.88631053e-02])

# %%
erk.portfolio_vol(erk.msr(.1, er[l], cov.loc[l,l]), ind["2018"][l].cov())
# Out:
# /var/folders/95/v2c39bhj1qj4tc84rkgvpkph0000gn/T/ipykernel_52366/2746956325.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   erk.portfolio_vol(erk.msr(.1, er[l], cov.loc[l,l]), ind["2018"][l].cov())
# 0.06346230747220709

# %%
erk.portfolio_vol(erk.gmv(cov.loc[l,l]), ind["2018"][l].cov())
# Out:
# /var/folders/95/v2c39bhj1qj4tc84rkgvpkph0000gn/T/ipykernel_52366/1666961551.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   erk.portfolio_vol(erk.gmv(cov.loc[l,l]), ind["2018"][l].cov())
# 0.054772453638838446
